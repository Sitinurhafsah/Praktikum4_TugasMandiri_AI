# %% [markdown]
# <a href="https://colab.research.google.com/github/Sitinurhafsah/Praktikum4_TugasMandiri_AI/blob/main/Siti%20Nurhafsah_230705103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix
from nltk.tokenize import word_tokenize
from keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.models import Model
from keras.layers import Input, Dense, LSTM, Dropout, concatenate
from keras.layers import Embedding
from keras.utils import plot_model

# %%
df = pd.read_csv('/content/all_agree.csv')
df.head()
# Out:
#                                                title          label  \
# 0  Masuk Radar Pilwalkot Medan, Menantu Jokowi Be...  non-clickbait
# 1  Malaysia Sudutkan RI: Isu Kabut Asap hingga In...  non-clickbait
# 2  Viral! Driver Ojol di Bekasi Antar Pesanan Mak...      clickbait
# 3  Kemensos Salurkan Rp 7,3 M bagi Korban Kerusuh...  non-clickbait
# 4  MPR: Amandemen UUD 1945 Tak Akan Melebar ke Ma...  non-clickbait
#
#    label_score
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0

# %%
df['label_score'].value_counts()
# Out:
# label_score
# 0    5297
# 1    3316
# Name: count, dtype: int64

# %%
def find_punc(x, punc):
  count = 0
  for char in x:
      if char == punc:
          count += 1
  return count

# %%
df['ccount'] = df['title'].apply(lambda x: find_punc(x, ','))
df['klctop_count'] = df['title'].apply(lambda x: find_punc(x, '.'))
df['excl_mark_count'] = df['title'].apply(lambda x: find_punc(x, '!'))
df['que_mark_count'] = df['title'].apply(lambda x: find_punc(x, '?'))
df['col_count'] = df['title'].apply(lambda x: find_punc(x, ':'))
df['semi_col_count'] = df['title'].apply(lambda x: find_punc(x, ';'))
df['sq_col_count'] = df['title'].apply(lambda x: find_punc(x, "'"))

# %%
df.shape
# Out:
# (8613, 10)

# %%
def find_uppercase(x):
    count = 0
    for char in x:
        if char.isupper() :
            count +=1
    return count

def find_lowercase(x):
    count = 0
    for char in x:
        if char.islower() :
            count += 1
    return count

def find_number(x):
    return len(re.findall('[0-9]', x))

# %%
df['uppercase_count'] = df['title'].apply(find_uppercase)
df['lowercase_count'] = df['title'].apply(find_lowercase)
df['number_count'] = df['title'].apply(find_number)

# %%
df.shape
# Out:
# (8613, 13)

# %%
import nltk
nltk.download('punkt_tab', quiet=True)

def clean(text) :
  # Lowering letters
  text = text.lower()
  # Removing Punctuations
  text = re.sub ('[,.!?:;\']',  '', text)
  # Tokenization
  word_tokens = word_tokenize(text)
  # Joining words
  text = (''.join(word_tokens))
  return text

# %%
df['cleaned_title'] = df ['title'].apply(clean)

# %%
df [['title', 'cleaned_title']]
# Out:
#                                                   title  \
# 0     Masuk Radar Pilwalkot Medan, Menantu Jokowi Be...
# 1     Malaysia Sudutkan RI: Isu Kabut Asap hingga In...
# 2     Viral! Driver Ojol di Bekasi Antar Pesanan Mak...
# 3     Kemensos Salurkan Rp 7,3 M bagi Korban Kerusuh...
# 4     MPR: Amandemen UUD 1945 Tak Akan Melebar ke Ma...
# ...                                                 ...
# 8608  Twice Rilis Teaser MV 'Feel Special' Jelang Co...
# 8609   Asap Karhutla Riau Mulai Merambah Ke Nias, BM...
# 8610  Tolak RUU Pertanahan, Ribuan Petani Siap Gelar...
# 8611  Ada Niat Tambah Momongan Tanpa Ikut Program Ha...
# 8612   TXT Akan Segera Comeback, Soobin Akui Gatal I...
#
#                                           cleaned_title
# 0     masukradarpilwalkotmedanmenantujokowibertemudp...
# 1        malaysiasudutkanriisukabutasaphinggainvasibabi
# 2     viraldriverojoldibekasiantarpesananmakananpaka...
# 3     kemensossalurkanrp73mbagikorbankerusuhansosial...
# 4          mpramandemenuud1945takakanmelebarkemana-mana
# ...                                                 ...
# 8608  twicerilisteasermvfeelspecialjelangcomebackkon...
# 8609  asapkarhutlariaumulaimerambahkeniasbmkgimbauwa...
# 8610  tolakruupertanahanribuanpetanisiapgelaraksidii...
# 8611  adaniattambahmomongantanpaikutprogramhamilfedi...
# 8612  txtakansegeracomebacksoobinakuigatalinginpamer...
#
# [8613 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['title', 'label', 'label_score', 'ccount', 'klctop_count',
#        'excl_mark_count', 'que_mark_count', 'col_count', 'semi_col_count',
#        'sq_col_count', 'uppercase_count', 'lowercase_count', 'number_count',
#        'cleaned_title'],
#       dtype='object')

# %%
X = df.iloc [:,3:]
y = df.iloc [:,2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.2,
random_state=77)

# %%
print (X_train.shape)
print (X_test.shape)
# Out:
# (6890, 11)
# (1723, 11)

# %%
X_train_title = X_train ['cleaned_title']
X_test_title = X_test ['cleaned_title']

X_train_punc = X_train.drop ('cleaned_title', axis = 1)
X_test_punc = X_test.drop ('cleaned_title', axis = 1)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train_title)

X_train_title = tokenizer.texts_to_sequences(X_train_title)
X_test_title = tokenizer.texts_to_sequences(X_test_title)

# %%
tokenizer.word_index
# Out:
# {'gara': 1,
#  'timnasu': 2,
#  'garaini': 3,
#  '0': 4,
#  '1': 5,
#  'undang': 6,
#  'timnasindonesiau': 7,
#  '16': 8,
#  'surabayamenggugat': 9,
#  '2020': 10,
#  '3': 11,
#  'cukainaik23': 12,
#  'hati': 13,
#  'topikpagi': 14,
#  'pdi': 15,
#  'siap': 16,
#  'hutke': 17,
#  'diawasidihongkongaktivisjoshuawongterbangkeberlin': 18,
#  'anak': 19,
#  'maruf': 20,
#  'x': 21,
#  'hatta': 22,
#  'zodiakmingguan16': 23,
#  '2019': 24,
#  '162020': 25,
#  'pemerintah': 26,
#  'leeminjung': 27,
#  'habisan': 28,
#  'luka': 29,
#  'tahundepanadakebijakancukaibaruapasajaisinya': 30,
#  'kejang': 31,
#  'garahalini': 32,
#  'junu': 33,
#  'cerai': 34,
#  'demokratsiapbantupemerintahanjokowi': 35,
#  'emak': 36,
#  'timorleste': 37,
#  'jadwalbolaakhirpekanligainggrisligaspanyolligaitalia': 38,
#  'gram': 39,
#  '11': 40,
#  'ksditunda': 41,
#  'videodetik': 42,
#  'aksi': 43,
#  'undangkpk': 44,
#  'pembangunansekolahindonesia': 45,
#  'madiun': 46,
#  'blak': 47,
#  'usd': 48,
#  'coba': 49,
#  'kis': 50,
#  'kemkominfososialisasikanmanfaatbantuansosialkepadakpmbpnt': 51,
#  'pkh': 52,
#  '20': 53,
#  'marcus': 54,
#  'indonesiamampupenuhiproteinhewanidalamnegeri': 55,
#  'empatmahasiswaindonesiadiaustraliapernahbunuhdiriapayangbisadicegah': 56,
#  'trick': 57,
#  'indonesiadermawan': 58,
#  '7k': 59,
#  'asean': 60,
#  'previewtimnasu': 61,
#  'fakta': 62,
#  'rizki': 63,
#  '2023': 64,
#  'besaran': 65,
#  'industriasuransioptimistiskembangkanpasardenganjkn': 66,
#  'faktalengkapproducex101yangperlukamutahu': 67,
#  'jadwalsiaranlangsungtimnasindonesiavsthailanddikualifikasipialadunia2022': 68,
#  'manfarfromhome': 69,
#  'jadwalmuvsleicestercitydiligainggrissiaranlangsungtelevisi': 70,
#  'peringatitahunbaruislambanyuwangikembaligelarfestivalmuharam': 71,
#  'viralemak': 72,
#  'warni': 73,
#  '2': 74,
#  'sudahdikafanibangkitlagiternyatapura': 75,
#  'puramatikarenabanyakutang': 76,
#  'ketemumarshandaraffiahmaddibuatsalahtingkah': 77,
#  'lagipestaganjadigrebekpolisipemudainingompoldicelana': 78,
#  'solskjaerdanieljamesmasihbisalebihbaguslagi': 79,
#  'gantikanjohnnyplatetaufikbasariditunjukjadiketuafraksinasdemmpr': 80,
#  'asapindonesiamulaiganggurodaekonomimalaysia': 81,
#  'ojekonlinetolakgabungdemoburuhkarenaalasanini': 82,
#  'ambondiguncangsejumlahgempadalamsemalam': 83,
#  'rayakanulangtahundufanajak1500anakyatimmainbersama': 84,
#  'dapatjatahwamenprojonggakjadibubardanmalahpujiprabowo': 85,
#  'pembalapaustraliaterjatuhtimindonesiajuaraietapeiitourdesiak': 86,
#  'maindikandangborneofcmaduraunitedpunyatargetini': 87,
#  'kabutasapmenebalpenerbanganlokaldilinggariaudibatalkan': 88,
#  'giselbantahtularidugemliaraurelcuekminum': 89,
#  'minumpamerkakinyilangseksi': 90,
#  'munculdigeekbenchgooglepixel4xl5gpunyaram8gbdansd855': 91,
#  'pernahdiajaktidurbarengdivilahinggahamilbibiakhirnyapolisikanpakkades': 92,
#  'pkbtidaksiapkanpenggantiimamnahrawi': 93,
#  'proyektollayangjakarta': 94,
#  'cikampekiitargetrampungakhirseptember': 95,
#  'kyaicholilprogrampetanimilenialhidupkanmentalsantri': 96,
#  'pesertabpjskesehatandiperkirakanbanyakyangpindahkekelaslebihrendah': 97,
#  'twicebeberrahasiatetapsoliddanberikabarsoalkondisimina': 98,
#  'mengenalnovianapengamencantikwisudawanterbaikdiuniversitasairlangga': 99,
#  'festivalgarisimaginerdigelarakhirpekanini': 100,
#  'kuasahukummintapemanggilanketuaumumfpisebagaisaksikasusmakardijadwalulang': 101,
#  'nagitaslavinaketakutannaiksepedamalahbikinfansgemas': 102,
#  'revisiuukpkdinilaiuntungkanmafiatambanginipenjelasannya': 103,
#  'ketuamrpbantahkepulanganmahasiswapapuakarenamaklumatyangdikeluarkan': 104,
#  'beginicaraadipatidolkendalamiperansebagaikasino': 105,
#  'fujifilmluncurkankamerax': 106,
#  'a7untukpemula': 107,
#  'usaidilantikanggotadprtermudahillarylasutlangsungserangrkuhp': 108,
#  '16ikutikualifikasipialaafcu': 109,
#  '16inihargatiketnya': 110,
#  'statustersangkaveronicakomandisoalpolriadapraperadilan': 111,
#  'ditangkapgegarakasusnarkobaputrisribintangtegaskantakterkaitpolitik': 112,
#  'presidenjokowimintapengesahanruukuhpditunda': 113,
#  '4alasansakitperutusaiberolahragasalahsatunyadehidrasi': 114,
#  '30065hektarelahanriauterbakar': 115,
#  'truktrontonjadipenyebabkecelakaantolcipularang': 116,
#  'sinopsissinetroncintabutaepisode74': 117,
#  '75tayangsenin8april2019': 118,
#  '8halyangdiperhatikanpriadarimusaatpertamakalibertemu': 119,
#  'agarhatilembuttaksekerasbatulakukan7amalansederhanaini': 120,
#  'siapkandiriuntuknostalgiadifilmthelionking2019': 121,
#  'tibadikantordprdsulselmassapelajardisambutmahasiswa': 122,
#  'terminal2bernamabandarasoettatravelokaapiikecolongan': 123,
#  'utusankhususpresidenakangelarmunastokohantaragama': 124,
#  'capimkpklilisayasetujurevisiuuuntukpenguatan': 125,
#  'setelahmelahirkanbayilaki': 126,
#  'laki10kaliberturut': 127,
#  'turutibuiniakhirnyadikaruniaianakperempuan': 128,
#  'hadapierarobotgeneraliindonesiatawarkanperencanaanpendidikananak': 129,
#  'warganyajadikorbanbupatipuncakmintastopbakutembak': 130,
#  'googleditudingmenakut': 131,
#  'nakutipenggunaiphonedengancelahkeamanan': 132,
#  'soalkembaliberpindahkeyakinaninitanggapanpengacarasteveemmanuel': 133,
#  '5potretkedekatanmayangsaridenganputrisematawayangmiripanakkembar': 134,
#  'kejamsekalihoaxtentangmeninggalnyabjhabibiesudah6kaliterjadisejak2012': 135,
#  'setelahkenaseranganjantungikercasillaskinilatihanlagi': 136,
#  'polisipanggilketumfpipengacaraeggisudjanabilangbegini': 137,
#  'netanyahuklaimiranpunyasitusrahasiaprogramsenjatanuklir': 138,
#  'aniesbaswedandoakanbjhabibiebisakembalisehat': 139,
#  'pakaimejadaripintubekasbawaamazonjadiperusahaanberkelas': 140,
#  'riofebrianberdukasangibumeninggaldunia': 141,
#  'airlanggahartartomintakadergolkardidprkawalkebijakanjokowi': 142,
#  'gagalcokoktersangkakerusuhanpapuainiyangditemukanpolisi': 143,
#  'sinopsissinetroncintasuciepisode299': 144,
#  '300tayangkamis4april2019': 145,
#  'kebakaranhutangunungciremaihanguskan150hektarelahan': 146,
#  'whoopigoldbergkritikdonaldtrumpsoalpengungsibahama': 147,
#  'dampakkabutasappuluhanribuwargaterserangispahinggawargasalatmintahujan': 148,
#  'dprddkimintagubernurwajiblaporjikagantiwalikotaanieskansudahselamaini': 149,
#  'kandidattuanrumahpialaduniau': 150,
#  '20delegasififainspeksistadionmanahansolo': 151,
#  'rossidanmarquezbersiteganglagidigpsanmarino': 152,
#  'pacarmuseringmerasapalingbenarmungkinmerekamasuk5zodiakini': 153,
#  'pengusahaajukannamacalonmenterikejokowiinidaftarnya': 154,
#  'ribuanwargabantulgelarkirabsiwurjelangupacarangurasenceh': 155,
#  'pasalunggasjalan': 156,
#  'jalandiruukuhpadakasuskonkretnyayukbaca': 157,
#  'belumamanolahtkpledakandimakobrimobsrondolditunda': 158,
#  'dugaankorupsikpurp12tdilaporkankekpkbeginirinciannya': 159,
#  'tipsamanberkendarajikakehilanganjarakpandangakibatkabutasap': 160,
#  'shandyauliapamerhasilusghidungmancungsangjabangbayijadisorotan': 161,
#  'gaspoldancyberjecksegeraberoperasidiindonesia': 162,
#  'sinopsisdramastill17episode23yangsejong': 163,
#  'shinhyesunmulaisalingterbuka': 164,
#  'kivlanzenperintahkanpembeliansenjataharusdibelisebelumpemilu': 165,
#  '7caramengetahuianakkesepianperhatikantandanya': 166,
#  'resepcekerayamdimsum': 167,
#  'blackpinkselalukenakankostumkerendigayodaejunmanayangterbaik': 168,
#  'tanggapipermohonanpknovantojaksasinggungsumpahdipengadilan': 169,
#  'massademopenuhijalangatotsubrotodepandprlalinditutup': 170,
#  '7tipsinibakalbantukalianmenentukanukuransepatusaatbelanjaonlinedijaminakurat': 171,
#  'hilangdigoogleplaystorebukalapakkamilakukanpembaharuan': 172,
#  'syahrinipamerkoloremashargaselangitpenyebabcelanareinobolongternodaterbongkar': 173,
#  'polritetapkan175tersangkakarhutla': 174,
#  '5koleksitasmewahlucintalunabikinjiwamiskinnetizenmeronta': 175,
#  'ronta': 176,
#  'berakhirpekandimalioborokunjungiduapameranseniini': 177,
#  'polusiasapsdncilincingpasangalatpenyaringudaradikelas': 178,
#  'polisiancamkeluarkanrednoticeuntukveronicakoman': 179,
#  'jokowiingatkantakadaistilahpengembalianmandatdiuukpk': 180,
#  'kronologilengkappemudadibandungtusukgadispujaankarenacintaditolak': 181,
#  'ini5bankyangtawarkanbungadepositotertinggi': 182,
#  'ganjarpranowolantikpengdakagamasulawesiutara': 183,
#  'stadionmanahanbarusiapdigunakanprosesrenovasisudah99': 184,
#  'rampung': 185,
#  'bnnklaimpenyelundupannarkotikakeindonesiamenurun30': 186,
#  'checkuphasilusgnikitamirzanibersyukurbayinyasehat': 187,
#  'plnserahkanpenyelidikanpenyebabpemadamanlistrikkebareskrim': 188,
#  'dearpenggunaiphonelakukanlangkahiniuntukhindari25ribumata': 189,
#  'matadiponselmu': 190,
#  'pengemudigo': 191,
#  'foodyanggunakansepedabantahmotornyadipakaianaknyakesekolah': 192,
#  'jackmaresmipensiundarialibabagroup': 193,
#  'mertesackeroezilmasihmamputingkatkanperformaarsenal': 194,
#  'memanasmahasiswapenolakuukpkbaru': 195,
#  'rkuhplemparbotol': 196,
#  'dorongpagar': 197,
#  'menkumhampecabutanpasporveronicakomansesuaiaturan': 198,
#  'btpnpenurunanbiratepositifturunkanbebanbunga': 199,
#  'mahasiswatetapdesakjokowiterbitkanperppukpkridaruratkorupsi': 200,
#  'mintadilibatkandalamrevisiuukpkakankirimsuratkedpr': 201,
#  'delonthamrintakperbolehkancalonistrimakanbanyakjelangharipernikahan': 202,
#  'kapalpenghancuramerikatantangcinasoallautcinaselatan': 203,
#  'pesertamagangdapatkarpetmerahjadipegawaipln': 248,
#  'beginijadinyaketikateslamodel3dimodifsuperceper': 249,
#  'anggotabpkakanditetapkanusaiujikelayakanterakhirselasa': 250,
#  '99namacintabukanfilmreligimeskimengambillatarkehidupanpesantren': 251,
#  'kuildithailandsembunyikanpuluhanbangkaiharimau': 252,
#  'tidaktakutgagal4zodiakinisukaambilrisikobesar': 253,
#  'beredarvideog': 254,
#  'dragonbigbangclubbingsambilmerokokdanmabuk': 255,
#  'mabukan': 256,
#  'aparatkembalisiagadijlgatsudekatgedungdprsiangini': 257,
#  'sandradewibikinirikarenatetapcantikdansingsetusaimelahirkan': 258,
#  'manchestercitypunyaskuattermahaldieropa': 259,
#  'akhirnyabesokjokowituruntemuiperwakilanmahasiswa': 260,
#  'kemarauwargacisaruasempatkesulitanmandikanjenazah': 261,
#  'alasanpemudapartaigolkardiymintawalikotayogyakartamengundurkandiri': 262,
#  'trumpkesepakatanperdaganganchinabisatercapaisaatpilpresas': 263,
#  'mantangubernurpapuabaratabrahamatururimeninggal': 264,
#  'andretaulanybeliharleydavidsonsportstersehargarp400': 265,
#  'anjutasetelahnabungselama25tahun': 266,
#  'plndorongpenggunaankendaraanlistriklewatkarnavaljakartalangitbiru': 267,
#  'beginiartinamaanakkeduasandradewi': 268,
#  'ada941pelanggarandiharipertamaperluasanganjilgenap': 269,
#  'thareqhabibiekesehatanbapakmulaistabil': 270,
#  'asusrilisduolaptopvivobookdenganbingkailayartipis': 271,
#  'pengembangdatabaseopensourcepostgresqlse': 272,
#  'asiaberkumpuldibali': 273,
#  'pro': 274,
#  'kontrapemindahanibukotabaruindonesiakekalimantanluhutkalaugakmaukesurgaaja': 275,
#  'setelahsuksesdiduniahiburanadlyfairuzjualankopi': 276,
#  'dampakkabutasaplionairgroupbatalkan21penerbangan': 277,
#  'viralselfiedimakambjhabibiebagaimanahukumnyadalamislam': 278,
#  'afghanistanserukantalibanterimagencatansenjata': 279,
#  'kondisiudarasemakinmemburuksekolahdidharmasrayadiliburkan3hari': 280,
#  'finiske': 281,
#  '11dimotogpsanmarinozarcocukuppuas': 282,
#  'terungkapcarakelvinmembakarmobilberisimayatpupungdandanaauliasiapkan8botolbensin': 283,
#  'transaksiimx2019ditargetkanlebihdarirp3miliar': 284,
#  'polisidalamipenyebarpesanberantaiyangajakpelajardemodimakassar': 285,
#  'rayakanharijadisavasagandengaeonstore': 286,
#  'kitkatgantikemasanplastikdengankertasorigami': 287,
#  'puanindustrispadapattingkatkanperekonomianlokal': 288,
#  'anggarankementerianpuprtahun2020disetujuirp12021triliun': 289,
#  'soalrevisiuukpkrelawannilailangkahjokowitepat': 290,
#  '10wisatajogjadanjawatengahdenganpanoramabaknegeridiatasawan': 291,
#  'kenalkanskuterhidrolikroda4canggihquadroqooderlistriksiapdiproduksi': 292,
#  '3tukangojektewasditembakkkbdiintanjaya': 293,
#  'singgungsoalmantandanikanasingalihginanjarmemangitufaktanya': 294,
#  'faozanrizalhabibie': 295,
#  'ainunbagairomeo': 296,
#  'julietindonesia': 297,
#  'sinopsissinetroncintabutaepisode126tayang16mei2019': 298,
#  'intelijenmiliterjermanperluaspenyelidikanpengaruhekstremkanandibundeswehr': 299,
#  'poppykellyngakusudahlaporkanbaliknikitamirzanihinggasiapkan13pengacara': 300,
#  'menhubharapkanpesawatr80jadikenyataan': 301,
#  'penuhgairahpetenisseksiiniciummesrapacarbaruusaigagaldiasterbuka': 302,
#  'bpkungkap14965masalahsenilairp1035triliun': 303,
#  'uukpkbaruberlakusejakdiundangkanjokowi': 304,
#  'digugatcalegkarenamenangkanmulancsgerindrasiapikutiproseshukum': 305,
#  'merawatsistemverifikasilegalitaskayu': 306,
#  'dinkesbatamimbauwargawaspadaikabutasap': 307,
#  'jksoalbanyaknyaottkpkkalaumakinkurangituprestasi': 308,
#  'kerusuhan22meivonis4bulanbuidisambutsukacitakeluarga': 309,
#  'pengendarayangtakbertanggungjawabharusdipidana': 310,
#  'finalaovstarleaguedigelarbesokpenontonbisadapathadiah': 311,
#  'wapresjusufkallasetujuadadewanpengawaskpktetapi': 312,
#  'klinsmanntakmengetahuileveltimnasjermansaatini': 313,
#  'botolairminumterpaparmatahariberdampakburukbagikesehatan': 314,
#  'bandaacehdiselimutikabutasap5000maskerdibagikankewarga': 315,
#  'luarbiasainimanfaataircucianberasuntukrambut': 316,
#  'pegawaikpksuratifraksididprmintatakpilihcapimyanglemahkankpk': 317,
#  'teukuwisnuterharuanakstmbentroktapiberhentisaatazanmagribbagikanvideomenyentuhini': 318,
#  'mantabberhijabdanbukausahafashioncutmeyriskainspirasininazatulini': 319,
#  'aniescabutkasasiperkaralahansodetanciliwungeraahokdima': 320,
#  'arumibachsinjadimodelcatwalkdadakancantikdanmempesona': 321,
#  'wapresjkjengukhabibiedirspad': 322,
#  'jelangtimnasu19indonesiavsiransayedakbarpoursanjungorangindonesia': 323,
#  'jikatakkunjungpenuhipanggilanveronicakomanbakaljadidpo': 324,
#  'ihsgmelemahpadasesiperdaganganpertamahariini': 325,
#  'irantangkaptigawargaaustralia': 326,
#  'polrestadepokbelumtelusurialiranuangptdamtour': 327,
#  'lucintalunabisniskopinetizenkritiknamabrandnya': 328,
#  'tradisiunik10muharramdinunukanbeliperkakasdapur': 329,
#  'kabutasapsirnadigempurhujanwargajambikinibisalepasmasker': 330,
#  'hasilligachampionsshakhtardonetskvsmanchestercity0': 331,
#  'ratuelizabethrupanyataksukalihatkatemiddletondanmeghanmarklepakaibendainididepanumum': 332,
#  'kemaraupanjangsejumlahdesadibalibaratalamikesulitanair': 333,
#  'narasibukusejarahkurangtunjukkanpercayadiribangsa': 334,
#  'resepcilokanti': 335,
#  'alotmengunyahtaklagisusah': 336,
#  'bjhabibiemeninggalduniaahyberbahagiakembalidenganbuainun': 337,
#  'walikotajambifashakembaliboyongpialawahanatatanugraha': 338,
#  'duaorangkorbanbentrokanditanahabangalamilukacukupparah': 339,
#  'sinopsisdramastill17episode3transformasiyangsejong': 340,
#  'responadikkandungbjhabibieseringditerpahoaxkabarduka': 341,
#  'dubesmalaysiahabibiebanyakmenyokongmalaysia': 342,
#  'kpktanggapidprpenegakanhukumtakbolehterikatkomitmenpolitik': 478,
#  'headlinejanjijokowiuntukpapuadamaidibumicenderawasihbakalterwujud': 479,
#  'viralkecelakaanbusmiranganjuk': 480,
#  'madiunkorbanselamatburonannarkobasudahditahanpolisi': 481,
#  '5tahunmerantaudijakartaakankahfendychowmemenuhiharapansangibu': 482,
#  'polisipemukulanggotadprdsumutdiamankanf': 483,
#  'gerindraakankonfirmasi': 484,
#  'imlowapresiasieksporulangkontainerlimbahplastikimpor': 485,
#  'sumseldikepungasapgubernurpergikunkerkemalaysia': 486,
#  'lunamayadimintasangcalonmertuatakcemburusaatdisuapifaisalnasimuddinfansgirang': 487,
#  'dihadapanpbbpakistanperingatkanancamangenosidadikashmir': 488,
#  'wengermenyesalgagalboyongmessikearsenal': 489,
#  'rusiatahanduakapalkoreautarasalahsatunyalepaskantembakan': 490,
#  'mudahnyachefselebritasajarkantipssederhanamemasak': 491,
#  'bappenasingatkankemenpartaksekadarkejarjumlahwisman': 492,
#  'ngeribakterisekarangbisatemukancarauntukkebaldariantibiotik': 493,
#  'srimulyanipantaudurasidisrupsiakibatsaudiaramcodiserang': 494,
#  'sonysubratadukungpemerintahtegasterhadappenyediamedsos': 495,
#  'rommybantahdakwaankpksoalintervensimenagbukananakbuahsaya': 496,
#  'moveonini5tandamantantakakanmengajakmubalikan': 497,
#  'rkuhpdendagelandanganmaksimalrp1jutainiceritaparapengemistajir': 498,
#  'boywilliamrayakanulangtahunmendiangadiklewatpostinganmengharukanini': 499,
#  'cukairokoknaik23': 500,
#  'indonesiarentanrokokilegal': 501,
#  'bmkgjabodetabektidakdiguyurhujanhariini': 502,
#  'mengenangchrisyekenapakaryasanglegendaristakpernahmati': 503,
#  'ihsgturunhingga182': 504,
#  'padajedamakansiang': 505,
#  'srimulyanibeberkanalasancukairokoknaik23': 506,
#  'di2020': 507,
#  'rasioutangluarnegeriindonesiaterhadappdbmenurun': 508,
#  'citacitatatuaiberbagaikomentarusaicurhatpanjangtakterimadifitnahsombongolehpenggemar': 509,
#  'biasadipujicantikbellahadidmendadakdisebutgantenggara': 510,
#  'garatampilsepertiini': 511,
#  'arilassogelarkonsertunggalsetelah27tahunberkiprah': 512,
#  'jalantolkunciranserpongditargetkanbeoperasiduabulanlagi': 513,
#  'penataantrotoarcikiniberbasisbudayasepanjangjalurtimdibuatmural': 514,
#  'mengalamikdrtbeginifaktatigasetiagara': 515,
#  'memasukipuncakkemaraubmkgprediksisuhusurabayabisa35derajat': 516,
#  'cetakduagolkegawangestoniababelsangatmenyenangkan': 517,
#  'seksinyapacarcristianoronaldogeorginarodriguezsaatsesifotobusanatransparan': 518,
#  'datangkepapuamendagriprioritaskansinkronisasiprogramtepatsasaran': 519,
#  '7unggulanindonesiamasukjalurnerakadichinaopen2019': 520,
#  'digitalisasisekolah38sekolahdinatunaakandiberi': 521,
#  "tablet''": 522,
#  'pembobolanbankpakaikudo2buronterlacakadadi': 523,
#  'targetinvestasipertaniannaikizininvestorharusdipermudah': 524,
#  'menangislahkarenainimanfaatmenangisuntuktubuh': 525,
#  'ridwankamilsebutimammasjiddinewyorkjadiinspirasiprogram': 526,
#  "englishforulama''": 527,
#  'pilkadatangerangselatankpuanggarkansantunankppsmeninggal': 528,
#  'terdugaterorisyangditangkapdensus88dijakutrencanakanpengeboman': 529,
#  'jokowihabibieisastatemanrespectedbypeople': 530,
#  'vickyprasetyodiam': 531,
#  'diamdekatisaritaabdulmukti': 532,
#  'iniprodusenkomponenlokalyangsokongproduksimobilesemka': 533,
#  'zodiakkesehatanbesokramalanzodiakkesehatanrabu11september2019tauruslelahscorpiostres': 534,
#  'persibvssemenpadang1': 535,
#  '1benarkahadaupayawalkout': 536,
#  'siapkansdmindustriberkompetenri': 537,
#  'singapurakerjasamapendidikanvokasi': 538,
#  'pesonaarielnoahdiulangtahunke': 539,
#  '38gantengnyagakluntur': 540,
#  'tidakmelakukankesalahanapa': 541,
#  'apabocah4tahuninidianiayaibutirihinggatewas': 542,
#  'ceritasoalbjhabibiedankrisis1998': 543,
#  'kronologibusmiravsmobilinnovasatukorbanselamatburonankasusnarkobainiidentitasnya': 544,
#  'jelangmusimhujanpemkotjaktimbeli10pompamobilemini': 545,
#  'dinaskesehatandanpendidikandimintabantusekolahyangterdampakasapindustridicilincing': 546,
#  'prakiraancuacabmkg33kotabesokjumat20september2019jambidansamarindadiselimutiasap': 547,
#  'sinopsissinetronorangketigatayangjumat3mei2019': 548,
#  'kpaitemuipelajarkorbandemosebutadadugaandipukulipolisi': 549,
#  'sinopsis100daysmyprinceepisode5jasadputramahkotaberhasilditemukan': 550,
#  'pencarisuakakembalitempatitrotoarkawasankebonsirih': 551,
#  'panas': 552,
#  'panas5minumanesasliindonesiainibikinsegar': 553,
#  'mahasiswaprotesuukpkdanrkuhpdprjanjipertemuanlanjutan': 554,
#  'masalahsemakinpanjangfairuzarafiqpernahalamikdrtdengangalihginanjar': 555,
#  'hasilmotogpmarquezjuaradikandangrossi': 556,
#  'gempam53guncangpapuabarattakberpotensitsunami': 557,
#  'artikeltentangbtssinggungkematiantragisjonghyunshineepicukemarahanfansk': 558,
#  'pop': 559,
#  'ikutgeramdengandpranjidukungdemomahasiswauntukwakilisuararakyat': 560,
#  'mercedesluncurkanmobilpertamaformulae': 561,
#  'pembunuhsalesmotoryangmayatnyaterjerattalitambangdihutandibekuk': 562,
#  'linkajapermudahpembayaranpbbdkijakarta': 563,
#  'ketikagusdurngakutakkenalbjhabibiebercandaatautidak': 564,
#  'rupiahmenguatihsgnaikkelevel637281': 565,
#  'nikitamirzanibanggatakperlujadicabe': 566,
#  'cabeanasyikhitunguangsawerannyanyidiklubmalam': 567,
#  'sebentarlagihondazoomerdirilisdiindonesiabanderolnyadibawahpcx': 568,
#  'previewliga1tirapersikabovspersibbandung': 569,
#  'ramalanzodiakbesokrabu11september2019ariesberistirahatlahtaurushati': 570,
#  'hatilebihboros': 571,
#  'ellysugigiputuskanpakaihijabbeberkanalasandansempatkhawatirakansepijobintipfotonya': 572,
#  'dibantaipsgrealmadridtelanrekorterburuksejak2003': 573,
#  'masyarakatakaliperluasanganjilgenapdenganplatnomorpalsu': 574,
#  '7manfaatbangunpagiuntukkesehatanfisikdanmental': 575,
#  'polisidimeksikotemukan44mayatyangdimutilasi': 576,
#  'setelahbertengkarlucintalunadanraffiahmadfotobareng': 577,
#  'soallivizhenginikataernestprakasa': 578,
#  'grupbarujypboystorydikritikhabis': 579,
#  'habisanusainumpangtampildik': 580,
#  'conthailand': 581,
#  'pindahibukotapengaruhiaruserakendaraanlistrik': 582,
#  'hotmanparismendadakpajangfotomesrasyahrinikelewatlangsinglagikangen': 583,
#  'viralbayiperempuaninidiberikopikarenaorangtuatakmampubelisusu': 584,
#  'dutertexitawarkanperjanjiangasjikaabaikanarbitrase': 585,
#  'iniamalansebelumsalatistisqauntukmintahujan': 586,
#  'waduhsebagianlampulalulintasdipurwakartamati': 587,
#  'bnisyariahresmikanpembentukanjespalembang': 588,
#  'kimkardashiansempattundamelahirkannorthwestdemimanicure': 589,
#  'hinodukunginvestigasikecelakaanmautdicipularang': 590,
#  'thepressmorallyindebtedtohabibie': 591,
#  'gebbyvestablak': 592,
#  'blakanakuidirinyatransgendermenangisungkapalasan19tahunsembunyikanfakta': 593,
#  '4inovasirumahpintaryangbikinandatenangsaattinggalkanrumah': 594,
#  'pendirikaskusandrewdarwisdilaporkanataskasuspemalsuan': 595,
#  'mesrasekalilihataksidariussinathryagendongdonnaagnesia': 596,
#  'hotnewsdicidukpolisinunungpositifpakainarkoba': 597,
#  'ditjenpas': 598,
#  'bnptbahas587napiterorisdirjenpasiniharusjadiperhatiankhusus': 599,
#  'perundingandamaias': 600,
#  'talibanruntuhpakistankecewaberat': 601,
#  'jelangputarankedualiga1pemainsemenpadangjalanitesvo2max': 602,
#  'gojekresmiberoperasidibandarasoekarno': 603,
#  'hattabeginicarapesannya': 604,
#  'surijabrikgadiscantikkeponakanlunamayayangternyatajagosurfing': 605,
#  'dianggaprasisgoogletranslatemintamaafkerakyataceh': 606,
#  'tampilmengenakanhijabawkarinhijrah': 607,
#  'ceritamatanajwakirimundanganterbukakeketuadpr': 608,
#  'selandiabarulawanpenyebarankontenterorismedimedsos': 609,
#  'lapakbijihplastikdilalapsijagomerah15mobildamkardikerahkan': 610,
#  'sukanontontapienggakadawaktucobain8aplikasistreamingfilmdandramaterpopulerini': 611,
#  'rezarahadianinginkanlebihbanyaklayardimomentumharifilmnasional': 612,
#  'linklivestreamingtimnasindonesiavsthailanddikualifikasipialadunia2022pukul1930wib': 613,
#  'pemancinginitaksengajatangkapikan': 614,
#  "alien''bermatabesar": 615,
#  'samsungboyongtime': 616,
#  'sport': 617,
#  "detonator''ketgs2019": 618,
#  'sudahdamaimelaneyricardoceritakanelzasyarifsempatsyok': 619,
#  'takbisamakan': 620,
#  'burungkolibripenyambungrantaikehidupandibangkabelitungterancampunah': 621,
#  'awkarinternyatasempatdiremehkansaatmendadakpesan3ribunasikotakuntukpendemo': 622,
#  'pemkabdharmasrayaakanperingatiharimaritimnasional': 623,
#  'hargaminyakmeroket15': 624,
#  'usaifasilitasminyakarabsaudidiserang': 625,
#  'petugasdishublaporkanaksipemukulandriverojoldisenenkepolisi': 714,
#  'tnitunjukputraaslipapuajadipangdamcendrawasih': 715,
#  'tipetemansepertiapakahkamucobaikutteskepribadianini': 716,
#  'rupslbbankbtpnsetujuiperubahansusunandireksi': 717,
#  'perangnarkobaguatemalakirim2000tentarakeperbatasan': 718,
#  'masyarakatadatpapuabutuhkepastianhukumpengelolaanhutan': 719,
#  'napolidanliverpoolsamakuatdibabakpertama': 720,
#  'korbaninvestasiuangdigitalnasabahditangseltertipurp35miliar': 721,
#  'indiabikinkompetisikentutterpanjangdanterkerasmauikutan': 722,
#  'mereknasionalpemerintahmaklumiesemkabimahanyagantimerek': 723,
#  'jamaahhajisuluttibadibandarasamratulangimanado': 724,
#  'senininikpkpanggilmelchiasmarcusmekengsebagaisaksi': 725,
#  'tolakruupertanahanribuanpetanisiapgelaraksidiistana': 726,
#  'dpresok': 727,
#  'kebakarandiapartemenkalibatacityduapenghuniluka': 728,
#  'tuntutditemuianggotadprdmahasiswainjakkawatberduridanlemparbotol': 729,
#  'inisebabtinggibadangabbyterusbertambahhinggacapai22meter': 730,
#  'vebbypalwintaakuisudahbelajartaarufsiapsegeranikah': 731,
#  'kabutasapbuatwargapadangsidimpuansumutmengap': 732,
#  'mengap': 733,
#  'bappenastegaskananggaranibukotabarutidakmasukrapbn2020': 734,
#  'menakerpemerintahsiapkanperlindunganskilldanjaminansosialbagipekerja': 735,
#  'hasillengkapligaitaliapekanketigadanklasemen': 736,
#  'laporkekomnashamikatanmahasiswasebutpolisialatpembunuh': 737,
#  'munculikananehdenganmataraksasainipenampakannya': 738,
#  'sinopsissinetroncintasuciepisode295tayangsenin1april2019': 739,
#  'fahrihamzahusulkanpresiden': 740,
#  'dprlakukanrapatkonsultasiruukuhp': 741,
#  'ratusankilosampahtertimbundipantaigoldcoast': 742,
#  'pencurianmobildinasemildidugaadaindikasiorangdalam': 743,
#  'dukungbisnisonlineposindonesialuncurkansamedayservice': 744,
#  'tigabulan400tangkiairdikirimkewargalamonganatasikekeringan': 745,
#  'lunatakcumajualankosmetiktapijugabukajasalesnyanyidanmainmusikbeginikatanetizen': 746,
#  'kisahpembunuhbayaran': 747,
#  "kelasteri''relamembunuhasaldibelikanrokok": 748,
#  'kissmerasadirugikandanmarahsaatharusmeninggaldiclassofliesfansmalahgemas': 749,
#  'habibiewafatlibwacanakanpenggunaanbanhitamdilengan': 750,
#  'berikanpendampingankeluargakemenpppakembangkanpuspaga': 751,
#  'kondisibjhabibiesemakinmembaik': 752,
#  'tabrakanberuntunduamobildanduamotorterjadidilentengagung': 753,
#  'sebanyak6025wargakalbartercatatmenderitaispa': 754,
#  'rupiahdibukamerangkaknaikusddekatileveltertinggiversusyen': 755,
#  '18sskbrimobmasihdisiagakandipapuabarat': 756,
#  'nyamarjadiemakemakberdasterpolisiiniberhasiltangkapbegalsadis': 757,
#  'massapetanidemodigedungdprdsumuttolakpengesahanruupertanahan': 758,
#  'dukungpembangunannasionaldenganpenguatanjabatanfungsional': 759,
#  'kabutasapkianpekatdinkeskobardirikanrumahsinggahoksigen': 809,
#  'upayakemnakertingkatkankompetensidankapasitasparatrainer': 810,
#  'penguatansdmmahasiswaasalpapuajadiwacanaperguruantinggidijawabarat': 811,
#  'hargaemasduniaturununtuk3hariberuntunapasebabnya': 812,
#  'pemerintahdandprsetujurevisiundang': 813,
#  'undangmd3': 814,
#  'wirantobicarakanpermasalahanpapuasaattemuieksmenlufiji': 815,
#  'raffiahmadtakterimamerrykerjaikutbudendymantanasistenbuatpengakuansumpahdemiallah': 816,
#  'btnpederelaksasiltvbakalpacupenyalurankprnonsubsidi': 817,
#  'polisikesulitantelusuridugaanterorulardiasramapapua': 818,
#  'caramenyimpantwitoranglainditwittertanpaketahuanfollower': 819,
#  'bpjsdefisitrp32triliunwamenkeukitaterlaludimanjasakitsedikitlangsungkers': 820,
#  'gerindrasetujuwacanawagubdkijakartalebihdarisatutapi': 821,
#  'dprakansahkanruuperkawinanbatasusiaperkawinanjadi19tahun': 822,
#  'pangeranharryberitandameghanmarklesudahmelahirkan': 823,
#  'jlgatsudekatdprditutupkendaraandialihkankejlgerbangpemuda': 824,
#  'bursatransferpemainliga1semenpadangtambah4pemainbaru': 825,
#  'hotmanparisngakumaindifirstclasspascafarhatabbaspamerlagidiswisslucumenggelikan': 826,
#  'jualrumahdemishakirakediamandenadaditawarkeluargamenteridenganhargasegini': 827,
#  'jajalmobillistrikanieskonvoimobilmewahbersamapebalapseangelael': 828,
#  'daihatsusigra2019masihpakaiaircirculatorbukanacdoubleblower': 829,
#  'trumpsiapbertemurouhanitanpaprasyarat': 830,
#  'kemenhubsiapkerjakankeretacepatjakarta': 831,
#  'surabaya': 832,
#  'yuhugrabpunyahalbarudiakhirtahunini': 833,
#  'viralpersamaangayakaiexodankrystalf': 834,
#  'bikinfansbapersendiri': 835,
#  'anggotakomisiiiipdippersilakancapimkpklobi': 836,
#  'lobi': 837,
#  'uberphk435karyawanbagianproduksidanteknik': 838,
#  'hebohsyahrinidanlunamayasepanggungbarengdishopeeramadantvshow': 839,
#  'hadapikentomomotadibabakkeduatommyharapbisatampilmaksimal': 840,
#  'besokpolisipanggilketumfpiterkaitkasusdugaanmakar': 841,
#  'pmselandiamintamaafatasskandalkekerasanseksualpartai': 842,
#  'lewatsenianak': 843,
#  'anakakantampilpercayadirihinggadewasa': 844,
#  'tanggapiserangandronekepabrikminyaksaudiaramcotrumpassiapmenembak': 845,
#  'wargadananggotatni': 846,
#  'polridimeranginjambisalatistisqa': 847,
#  'sriwijayaairdimintapatuhiksmgarudaindonesia': 848,
#  'pelajardemorusuhdidprbemunjsemogainibukandimanfaatkanoknum': 849,
#  'ulamasayangkanagendapolitikgunakansumpahalquran': 850,
#  'viralayahmarahianaknyayangikutdemotuaiprodankontra': 851,
#  'bajakahantaraobatdanracunsertakeikhlasanwargaibukotabaruindonesiamemberikannyagratis': 852,
#  'suzypostingekspresiseriusdivagabondmalahditanyasoalresep': 853,
#  'hincasbymintakaderpdpastikanpemerintahanjadilebihbaik': 854,
#  'kasussuapimporikankpkcegah2orangkeluarnegeri': 855,
#  'kivlanzenajukanpermohonanizinberobatdenganterbatuk': 856,
#  'batuk': 857,
#  'jikaasingingelarperundinganpelucutansenjatanukliriniyangdimintakoreautara': 858,
#  'livestreamingtvonlineindosiarpersijajakartavsbaliuniteddiliga12019aksesdisini': 859,
#  '4faktadibalikperhelatanbalkonjazzfestival2019': 860,
#  'lagunyadiviralkandutasheilaon7beginitanggapanlangitsore': 861,
#  '8pasanganzodiakyanghubungannyabertahanlamavirgodancapricornterciptasatusamalain': 862,
#  'cabulibocahenamtahunpedagangsusukelilingdibekasidiringkus': 863,
#  'taufikhidayatungkappesanbjhabibieketimpialathomas1998': 864,
#  'iphone11prodenganwarnaemassepipembeli': 865,
#  'warnarambutlagihitsdiinstagramcobayuk': 866,
#  'malaysiaberencanatidakpenjarakanpenggunanarkoba': 867,
#  'bersiaplawanbarcelonavalenciajustrupecatpelatihmarcelino': 868,
#  'imporricapaiusd142miliarturun15': 869,
#  'dishubdkiperluasanganjilgenapharipertamaperbaikikualitasudara': 870,
#  'tayangmalaminikamis19september2019aksibrucewilisdifilmviceditranstvpukul2300wib': 871,
#  'mantandirutpetraljaditersangkakorupsi': 872,
#  '5pilihanolahragasaathamilmudajalankakihinggapilates': 873,
#  '41kaderperindosumutlolosparlemensekjendppingatkanjangankorupsi': 874,
#  'dprusuldewanpengawaskpktakdipilihpemerintah': 875,
#  'pgiprihatinupayapelemahankpkiniaspirasinya': 876,
#  'wanitadengantubuhberisiterbuktibikinprialebihbahagia': 877,
#  'gyuriekskaradiam': 878,
#  'diampacaribrondongtajirintipfoto': 879,
#  'fotokencanmereka': 880,
#  'kepadapengusahajokowiingatkanketidakpastianekonomiglobal': 881,
#  'sebabtinggimejaloketjanganlebihdari1meter': 882,
#  'beredarvideopolisiteriakitnidimespatitnialinipenjelasanpolri': 883,
#  'ihsgdibukamenguattipiske6244': 884,
#  '10potretliburandiansastrobersamasuamidan2anaknya': 885,
#  'pangkastengkulaktbbmpertaminarewuluinisiasiprogramjapangmas': 886,
#  'menolakrevisiuukpkkatakapitraamperaitumakar': 887,
#  'crowngroupraihduapenghargaanbergengsidiaustralia': 888,
#  'caripemainesportsberbakatwatonggelarmlbbcompetition': 889,
#  'adachrisyedigoogledoodlehariini': 890,
#  'ekspengamencantikdisurabayainijadiwisudawanterbaikdiunairipk': 891,
#  'nya394': 892,
#  'queendomtanggapikabarsoalpesertabayarsendirisemuabiayapenampilan': 893,
#  'savethechildrenpemerintahabaikananakkorbankabutasap': 894,
#  '9pabriktekstiltutupmenperintakadarevitalisasipermesinan': 895,
#  'megawatiterekamtolaksalamisuryapalohisyaratkanpecahkongsi': 896,
#  'garamimpiburukperempuaninitelancincinpertunangannya': 897,
#  'tyasmirasihkompakanjalaniprogramdietbarengsuamitanpaolahraga': 898,
#  'melihatlebihdekatlianglahatuntukbj¬†habibie': 899,
#  'responsrahmaddarmawansaatdikabarkanakantanganitimnasindonesia': 900,
#  'dorongpenggunaankendaraanlistrikpermenhubdipercepat': 901,
#  'akanhadirdiindonesiavivov17prorilisdiindia20september': 902,
#  'eramobillistrikpenggunaanpelumasbisaturun50persen': 903,
#  'peluangkorupsidalamruupertanahan': 904,
#  'barbiekumalasaribakalkeamerikabarengboywilliambeginiceritanya': 905,
#  'bukuubocahgairahkanminatbacarumahbelajarjuara': 906,
#  'menkominfodorongpemanfaatankecerdasanbuatanuntuklayananpemerintahan': 907,
#  'pejetskiindonesiajuaraip1aquacrossdiamerika': 908,
#  'duagolrealmadridkegawangpsgdianulirvarbeginipenjelasannya': 909,
#  'genjotpajakdaripariwisatadisparbuddkigandengtraveloka': 910,
#  'lapindotakbayarutangrp17tkemenkeulayangkantagihanlagi': 911,
#  'banyaktempathiburanmalamditutuppajakdkitakcapaitarget': 912,
#  'ronaldoempatgolportugallumatlithuania5': 913,
#  'eksporindustrikerajinancapai870jutadolaras': 914,
#  'lucintalunajatuhterguling': 915,
#  'gulingdigurunsaharalalukegugurandokterterkejutlihatinidiusg': 916,
#  'resmidiluncurkaninigebrakanbarudifestivalfilmindonesia2019': 917,
#  'fahrihamzahusuljokowisegeralantikfirlicsinialasannya': 918,
#  'korselsebutsaudimintabantuanperkuatpertahananudara': 919,
#  'pembangunanpengolahansampahsunterdimulainovember2019': 920,
#  'dipukulidebtcolectorlaporpolisisudahsetahunlebihmasihnggakjelas': 921,
#  '5halmenarikbalkonjazzfestival2019pasarbalkonhinggaditutupyurayunita': 922,
#  'inggrisizinkanmahasiswaasingtinggalduatahunpascalulus': 923,
#  'ruukuhpditundaketuadprberharapbisaturunkantensipolitik': 924,
#  'lelangproyekjakartainternationalstadiumdiprotesapakatakementerianpupr': 925,
#  'bebbyfeymintarumahdanmobilmewahsebagaisyaratdamaidengansangyoutuberterkenal': 926,
#  'filmloveforsale2luncurkantrailerperdanadengancarauniksepertiapa': 927,
#  'tigapejabatpemkotinginmajupilkadatangsel2020apakataairin': 928,
#  'yusrilnilaidewanpengawasbisamelekatdengankpk': 929,
#  'pelatihtimnasindonesiasebutduapemainthailandinipunyakualitaspembeda': 930,
#  'koreadramaawards2019kimjiwondanyooinnasainganinidaftarlengkapnominasinya': 931,
#  '19tekukiranfakhrihusainisemogajadipelipurlara': 932,
#  'nagitaslavinaogahmenginapdihotelmewahmilikmamarietaraffiahmadungkapalasannya': 933,
#  'cukainaikpicurokokilegalpemerintahintensifkanpenindakan': 934,
#  'novantokembalikanuangpenggantikorupsiiniperinciannya': 935,
#  'sinopsissinetroncintasuciepisode318': 936,
#  '319tayangkamis18april2019': 937,
#  'jadisorotaninilahbedareaksikipertimnasindonesiadanwingerthailand': 938,
#  'kasuskorupsigubernurkeprikpkperiksakadispupr': 939,
#  'kembalinaikutangluarnegeriindonesiatembusrp5534triliun': 940,
#  'polisipersilahkanveronicakomantempuhupayahukumsoalstatustersangka': 941,
#  'kivlanzenakanajukannotakeberatanuntuktolakdakwaanjaksa': 942,
#  'viraljeritankorbantabrakanmautdisumaterabikinmerinding': 943,
#  'prediksibosjaguarlandroversoalmobillistrikyangjaminbikinciut': 944,
#  'lolosdarihukumanmatikekayaanbandarnarkobainikalahkansandiagauno': 945,
#  'ibukotabarudikritikridwankamilterlaluluasinikomentargubernurkaltim': 946,
#  'kontaktembakdiilagapapuaseorangbalitatewas': 947,
#  'kisahkorbanpenculikanisisalamikekerasanseksualhinggadijual20kali': 948,
#  'aplikasibukalapakmenghilangdarigoogleplaystoreadaapa': 949,
#  'garudaluncurkanaplikasilayananpengirimanlogistik': 950,
#  'surprisehargatiketkejepanglebihmurahdaripadajakarta': 951,
#  'pekanbaru': 952,
#  '8tipsagarbagasiamandantidakdiboboldibandara': 953,
#  'bocahdibekasidisebuttewaskarenabullykpadimbaukeluargamelapor': 954,
#  'hijaberssudahtepatkahcaramerawatrambutmucaritahulewatkuisiniyuk': 955,
#  'investasikorseldiyakiniperkuatstrukturmanufakturindonesia': 956,
#  'kenali10tahapanpendaftarancpns2019dandokumenyangdiperlukangurudannakespalingdicari': 957,
#  'tipsbeliemasdigitalbisadicicillaludijuallagi': 958,
#  'dprakanpilih5pimpinankpkperiode2019': 959,
#  '2023malamini': 960,
#  '5fiturmenariktoyotacalyayangwajibdiketahui': 961,
#  '35orangtewasdipestapernikahanakibatseranganpasukanafghanistan': 962,
#  'tukanggalondanairminumnyalonpilkadatangsel': 963,
#  'berbagaikeluhanpengendaradiharipertamapenerapanperluasanganjilgenap': 964,
#  'ceritalucujinbtstaksengajapapasandengansugasaatbersepedakekantor': 965,
#  'polri': 966,
#  'tnigelarapelpengamananjelangunjukrasadidpr': 967,
#  'anakbjhabibienyatakanayahnyatakakandibawakejerman': 968,
#  'terpaparkabutasapkarhutlajambelajarsmadisumseldimundurkan': 969,
#  'postingfototeasercomebackleedonghaesuperjuniormalahbuatfansngakakgara': 970,
#  'rasioelektrifikasibisa100': 971,
#  'denganenergiterbarukan': 972,
#  'sebelumdisiksasuamitigasetiagararayakanulangtahunpernikahan': 973,
#  'daftar8unggulantersingkirdibabakpertamachinaopen2019adawakilindonesia': 974,
#  'mintapolisitenanghadapidemomahasiswaprabowocontohkanprancis': 975,
#  '11orangtewasakibatbanjirbandangdiindia28000orangdievakuasi': 976,
#  'miliarderjepangsebutbrexitmustahildiwujudkan': 977,
#  'pasokanavturkebandarakertajatijauhdibawahbandarasoekarno': 978,
#  'lanyallabikingegerusaiterpilihjadiketuadpdinialasannya': 979,
#  'perhitungansuarabelumselesaiadlyfairuzdipastikanmenujugedungdprri': 980,
#  'sempatalamipendarahanirishbellalebihberhati': 981,
#  'bppdbaliajukanrevisipasalrkuhpyangdinilaiganggupariwisata': 982,
#  'kpkgeledahkantordinaspudanpendidikankepri': 983,
#  'massaaksigejayanmemanggilmulaiberkumpuldipertigaancolombo': 984,
#  'penyebabaplikasitemposempathilangdariplaystore': 985,
#  'jeongyeontwicekagetsaattahuchaeryeongitzyternyatatetangganya': 986,
#  'selfiedenganhabibie': 987,
#  'santanhinggadaunpandaninibahanpelengkapjajanantradisional': 988,
#  'teganyapabrikminyakgorengdimedanpecatkaryawanjelanglebaran': 989,
#  'catatanimpresifcristianoronaldokegawangatleticobakalberlanjut': 990,
#  'gubernurjabarperkuatkoordinasidengankabupatendankotadikopdar': 991,
#  'gwpp': 992,
#  '6perampokbersebotembakwargahinggatewasdisumsel': 993,
#  'hadirditmpkalibatawargatimorlestehabibiepahlawansaya': 994,
#  'pertemuanbilateralawalikegiatanmenludihighlevelweeksidangumumpbb': 995,
#  'volvotruckshadirkantrukdengansisteminjeksidilengkapiebs': 996,
#  'kabutasapbikinpenerbangandibanjarmasinterganggu': 997,
#  'perluasanganjilgenapbanyakpelanggardijalangunungsahari': 998,
#  'franklampardinginrekrutpemaininiuntukchelsea': 999,
#  'penurunanpenjualanmobildi2019berdampakkeasuransi': 1000,
#  ...}

# %%
vocab_size = len(tokenizer.word_index)
vocab_size
# Out:
# 7735

# %%
lengths = []
for sentence in X_train_title:
    lengths.append(len(sentence))

print('Longest sentence\t:', max(lengths))
print('Shortest sentence\t:', min(lengths))
print('Average length\t\t:', np.mean(lengths))
# Out:
# Longest sentence	: 6
# Shortest sentence	: 1
# Average length		: 1.1435413642960812

# %%
X_train_title = sequence.pad_sequences(X_train_title, maxlen=19)
X_test_title = sequence.pad_sequences(X_test_title, maxlen=19)

# %%
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.array([0, 1]), y=y_train.values)
class_weights
# Out:
# array([0.80868545, 1.30988593])

# %%
class_weight_dict = dict(enumerate(class_weights))
class_weight_dict
# Out:
# {0: np.float64(0.8086854460093896), 1: np.float64(1.3098859315589353)}

# %%
print(X_train_title.shape)
print(X_test_title.shape)
# Out:
# (6890, 19)
# (1723, 19)

# %%
tf.random.set_seed(99)

lstm_input = Input(shape=(19,))
lstm = Embedding(input_dim=vocab_size+1, output_dim=32)(lstm_input)
lstm = LSTM(3)(lstm)
lstm = Dropout(rate=0.5)(lstm)
lstm = Dense(3, activation='sigmoid')(lstm)

lstm_model = Model(inputs=lstm_input, outputs=lstm)

# %%
dense_input = Input(shape=(10,))
dense = Dropout(rate=0.5) (dense_input)
dense = Dense(3, activation='sigmoid') (dense)
dense_model = Model(inputs=dense_input, outputs=dense)

# %%
print(X_train_punc.shape)
print(X_test_punc.shape)
# Out:
# (6890, 10)
# (1723, 10)

# %%
concat = concatenate ([lstm_model.output, dense_model.output])
concat = Dense(6, activation='sigmoid')(concat)
concat = Dense(1, activation='sigmoid')(concat)
model = Model(inputs=[lstm_model.input, dense_model.input], outputs=concat)

# %%
plot_model(model)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    [X_train_title, X_train_punc],
    y_train,
    epochs=4,
    batch_size=64, class_weight=class_weight_dict,
    validation_data=([X_test_title, X_test_punc], y_test))
# Out:
# Epoch 1/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.4769 - loss: 0.6935 - val_accuracy: 0.4045 - val_loss: 0.6962
# Epoch 2/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4734 - loss: 0.6928 - val_accuracy: 0.4074 - val_loss: 0.6964
# Epoch 3/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5422 - loss: 0.6894 - val_accuracy: 0.4498 - val_loss: 0.6926
# Epoch 4/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6019 - loss: 0.6787 - val_accuracy: 0.4997 - val_loss: 0.6899

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss','val_loss'])
